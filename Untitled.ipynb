# %%
import pandas as pd
df = pd.DataFrame({'name':['a','b','c'], 'count':[12,24,18]})
z.show(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df = pd.DataFrame({'name':['a','b','c'], 'count':[12,24,18]})
#       3 z.show(df)
#
# ModuleNotFoundError: No module named 'pandas'
